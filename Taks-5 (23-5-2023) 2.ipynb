# %%
import matplotlib.pyplot as plt

# %%
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [23, 56, 41, 62, 19]
data = [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]
labels = ['Apple', 'Banana', 'Orange', 'Mango']
sizes = [30, 25, 15, 30]
x = [1, 2, 3, 4, 5]
y = [2, 5, 3, 6, 4]

# Create a figure with 2x2 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot bar chart in the first subplot (top-left)
axs[0, 0].bar(categories, values)
axs[0, 0].set_title('Bar Chart')
axs[0, 0].set_xlabel('Categories')
axs[0, 0].set_ylabel('Values')

# Plot histogram in the second subplot (top-right)
axs[0, 1].hist(data)
axs[0, 1].set_title('Histogram')
axs[0, 1].set_xlabel('Data')
axs[0, 1].set_ylabel('Frequency')

# Plot pie chart in the third subplot (bottom-left)
axs[1, 0].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
axs[1, 0].set_title('Pie Chart')

# Plot scatter plot in the fourth subplot (bottom-right)
axs[1, 1].scatter(x, y)
axs[1, 1].set_title('Scatter Plot')
axs[1, 1].set_xlabel('X Values')
axs[1, 1].set_ylabel('Y Values')

# Adjust the spacing between subplots to avoid overlapping
plt.tight_layout()


plt.show()
